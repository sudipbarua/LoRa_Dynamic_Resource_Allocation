# %%
import numpy as np
import glob

log_files = glob.glob('log/*.npy')
logs = [np.load(f, allow_pickle=True) for f in log_files]

# %%
logs
# Out:
# []

# %%
np.load('/home/sudip/IoT-MAB/logs/nodeList_bs1_nodes10.npy', allow_pickle=True)
# Out:
# array([[0.00000000e+00, 4.99851076e+03, 5.57209451e+03, 1.20000000e+01,
#         1.00000000e+00, 1.25000000e+02, 5.00000000e+01, 8.00000000e+00,
#         4.25000000e+00, 0.00000000e+00, 1.00000000e+00, 1.40000000e+01,
#         0.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 4.20944436e+03, 4.51396566e+03, 1.20000000e+01,
#         1.00000000e+00, 1.25000000e+02, 5.00000000e+01, 8.00000000e+00,
#         4.25000000e+00, 0.00000000e+00, 1.00000000e+00, 1.40000000e+01,
#         0.00000000e+00, 0.00000000e+00],
#        [2.00000000e+00, 5.06691599e+03, 3.53991921e+03, 1.20000000e+01,
#         1.00000000e+00, 1.25000000e+02, 5.00000000e+01, 8.00000000e+00,
#         4.25000000e+00, 0.00000000e+00, 1.00000000e+00, 1.40000000e+01,
#         0.00000000e+00, 0.00000000e+00],
#        [3.00000000e+00, 3.70658325e+03, 4.56640062e+03, 1.20000000e+01,
#         1.00000000e+00, 1.25000000e+02, 5.00000000e+01, 8.00000000e+00,
# ...
